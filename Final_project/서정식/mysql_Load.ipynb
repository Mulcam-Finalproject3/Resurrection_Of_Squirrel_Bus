# %%
import os
import csv
import mysql.connector

# MySQL 설정
def action_mysql():
    import os
    import csv
    import mysql.connector
    mydb = mysql.connector.connect(
        host="15.152.232.36",
        user="multi",
        password="Campus123!"
    )
    mycursor = mydb.cursor()
    mycursor.execute("CREATE DATABASE IF NOT EXISTS MT_Project_DB")
    mycursor.execute("USE MT_Project_DB")


action_mysql()

# %%
# Bus_Location 테이블 생성
columns1 = [
    "Node_Id",
    "Ars_Id",
    "Station_Name",
    "X",
    "Y"
]

Bus_Location_table = f"CREATE TABLE IF NOT EXISTS `Bus_Location` ("
for column in columns1:
    if column == "Node_Id" or column == "Ars_Id" :
        Bus_Location_table += f"`{column}` INT, "
    elif column == "X" or column == "Y" :
        Bus_Location_table += f"`{column}` FLOAT, "
    else:
        Bus_Location_table += f"`{column}` VARCHAR(255), "
Bus_Location_table = Bus_Location_table[:-2] + ")"
mycursor.execute(Bus_Location_table)

# %%
# Visitor 데이터 삽입
count = 0
for filename in sorted(
    os.listdir("C:/Users/Sun/Desktop/DB/월별데이터/월별방문자수"),
    key=lambda x: int(x.split("_")[2].replace("월", "")),
):
    file_path = os.path.join("C:/Users/Sun/Desktop/DB/월별데이터/월별방문자수", filename)
    file_path = file_path.replace("\\", "/")

    # 파일명에서 지역, 기초지자체명, year, month를 추출
    _, year_str, month_str, region, *_ = filename[:-4].split("_")
    month = int(month_str.replace("월", ""))
    year = int(year_str)

    # 파일 읽기 & DB에 데이터 삽입
    with open(file_path, encoding="cp949") as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            insert_row_sql = f"INSERT INTO `Visitor` (`{columns1[0]}`, `{columns1[1]}`, `{columns1[2]}`, `{columns1[3]}`, `{columns1[4]}`, `{columns1[5]}`) VALUES ('{region}', '{row[0]}', {int(year)}, {int(month)}, {row[1]}, {row[2]})"
            mycursor.execute(insert_row_sql)

        count += 1
        print(f"{filename} 파일을 저장했습니다.")

# %%
# 서울시버스정류소위치정보 엑셀 데이터 입력하기

import pandas as pd
import pymysql
import glob
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# MySQL 설정
username = 'multi'
password = 'Campus123!'
hostname =  '15.152.232.36'
database_name = 'MT_Project_DB'
desired_table_name = 'Bus_Location'
cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
cursor = cnx.cursor()

# 파일 불러오기
files = glob.glob("/Users/seojeongsik/TIL/Final_project/data/서울시버스정류소위치정보.xlsx")
df_list = [pd.read_excel(file) for file in files]
df = pd.concat(df_list, ignore_index=True)
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(user=username,
                               pw=password,
                               db=database_name,
                               host=hostname))
Session = sessionmaker(bind=engine)
session = Session()
try:
    df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()
cursor.close()
cnx.close()

# pymysql.err.InternalError: (1366, "Incorrect string value: 'job' for column at row 1")
# 에러가 나올 시 cmd창으로 mysql에 접속하여 아래에 코드를 칠 것
# ALTER DATABASE [DB명] CHARACTER SET = utf8mb4 COLLATE = utf8mb4_unicode_ci;

# %%
# 버스노선ID 엑셀 데이터 입력하기

import pandas as pd
import pymysql
import glob
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# MySQL 설정
username = 'multi'
password = 'Campus123!'
hostname =  '15.152.232.36'
database_name = 'MT_Project_DB'
desired_table_name = 'Bus_Route_Id'
cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
cursor = cnx.cursor()

# 파일 불러오기
files = glob.glob("/Users/seojeongsik/TIL/Final_project/data/서울시버스노선ID정보(20230613).xlsx")
df_list = [pd.read_excel(file) for file in files]
df = pd.concat(df_list, ignore_index=True)
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(user=username,
                               pw=password,
                               db=database_name,
                               host=hostname))
Session = sessionmaker(bind=engine)
session = Session()
try:
    df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()
cursor.close()
cnx.close()

# %%
# 서울시 표준링크 매핑정보_2023.03 엑셀데이터

import pandas as pd
import pymysql
import glob
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# MySQL 설정
username = 'multi'
password = 'Campus123!'
hostname =  '15.152.232.36'
database_name = 'MT_Project_DB'
desired_table_name = 'Bus_Link_Mapping'
cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
cursor = cnx.cursor()

# 파일 불러오기
files = glob.glob("/Users/seojeongsik/TIL/Final_project/data/서울시 표준링크 매핑정보_2023년3월 기준.xlsx")
df_list = [pd.read_excel(file) for file in files]
df = pd.concat(df_list, ignore_index=True)
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(user=username,
                               pw=password,
                               db=database_name,
                               host=hostname))
Session = sessionmaker(bind=engine)
session = Session()
try:
    df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()
cursor.close()
cnx.close()

# %%
# 노드별 링크정보_2023 (서울, 경기, 인천).csv.xlsx 엑셀데이터

import pandas as pd
import pymysql
import glob
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# MySQL 설정
username = 'multi'
password = 'Campus123!'
hostname =  '15.152.232.36'
database_name = 'MT_Project_DB'
desired_table_name = 'Bus_Node_Link'
cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
cursor = cnx.cursor()

# 파일 불러오기
files = glob.glob("/Users/seojeongsik/TIL/Final_project/data/노드별 링크정보_2023 (서울, 경기, 인천).csv.xlsx")
df_list = [pd.read_excel(file) for file in files]
df = pd.concat(df_list, ignore_index=True)
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(user=username,
                               pw=password,
                               db=database_name,
                               host=hostname))
Session = sessionmaker(bind=engine)
session = Session()
try:
    df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()
cursor.close()
cnx.close()

# %%
#통근·통학시_이용하는_교통수단 
def load_mysql_csv(databasename, tablename, filename):
    import pandas as pd
    import pymysql
    import glob
    from sqlalchemy import create_engine
    from sqlalchemy.orm import sessionmaker
    import os

    # MySQL 설정
    username = 'multi'
    password = 'Campus123!'
    hostname =  '15.152.232.36'
    database_name = databasename
    desired_table_name = tablename
    current_working_directory = os.getcwd()
    
    cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
    cursor = cnx.cursor()

    # 파일 불러오기
    files = glob.glob(current_working_directory+"/data/"+filename)
    df_list = [pd.read_csv(file) for file in files]
    df = pd.concat(df_list, ignore_index=True)
    engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                        .format(user=username,
                                pw=password,
                                db=database_name,
                                host=hostname))
    Session = sessionmaker(bind=engine)
    session = Session()
    try:
        df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
        session.commit()
    except:
        session.rollback()
        raise
    finally:
        session.close()
    cursor.close()
    cnx.close()

# %%
load_mysql_csv("MT_Project_DB", "pra","시군구별 생활업종 사업체수_약국.csv")

# %%
import os
os.getcwd()
# Out:
# '/Users/seojeongsik/Multi_Final_Project/Final_project/서정식'

# %%
# mysql에서 데이터프레임 불러오기
def call_dataframe(table):
    import pandas as pd
    from sqlalchemy import create_engine

    db_connection_str = 'mysql+pymysql://multi:Campus123!@15.152.232.36/MT_Project_DB'
    db_connection = create_engine(db_connection_str)

    pop_table = pd.read_sql("SELECT * FROM {}".format(table), con=db_connection)
    print("컬럼명 : ",list(pop_table.columns))

    # 데이터프레임
    return pop_table

# %%
call_dataframe("Bus_Location")
# Out:
# 컬럼명 :  ['NODE_ID', 'ARS_ID', '정류소명', 'X좌표', 'Y좌표']
#          NODE_ID  ARS_ID           정류소명         X좌표        Y좌표
# 0      100000001    1001        종로2가사거리  126.987750  37.569765
# 1      100000002    1002    창경궁.서울대학교병원  126.996566  37.579183
# 2      100000003    1003      명륜3가.성대입구  126.998340  37.582671
# 3      100000004    1004       종로2가.삼일교  126.987613  37.568579
# 4      100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243
# ...          ...     ...            ...         ...        ...
# 12565  124000334   25995          우성아파트  127.139339  37.550386
# 12566  124000333   25996          우성아파트  127.140046  37.550643
# 12567  124000332   25997           조일약국  127.123596  37.533630
# 12568  124000331   25998           성내시장  127.125497  37.536155
# 12569  124000330   25999    천호우체국.로데오거리  127.127337  37.540343
#
# [12570 rows x 5 columns]

# %%
# 버스 시간별 재차인원 csv
import pandas as pd
import pymysql
import glob
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# MySQL 설정
username = 'multi'
password = 'Campus123!'
hostname =  '15.152.232.36'
database_name = 'MT_Project_DB'
desired_table_name = 'Bus_Num_Passengers'
cnx = pymysql.connect(user=username, password=password, host=hostname,charset='utf8')
cursor = cnx.cursor()

# 파일 불러오기
files = glob.glob("/Users/seojeongsik/TIL/Final_project/data/Bus_Num_Passengers.23.06.05-06.11_2.xlsx")
df_list = [pd.read_excel(file) for file in files]
df = pd.concat(df_list, ignore_index=True)
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
                       .format(user=username,
                               pw=password,
                               db=database_name,
                               host=hostname))
Session = sessionmaker(bind=engine)
session = Session()
try:
    df.to_sql(desired_table_name, con=engine, if_exists='replace', index=False, chunksize = 1000)
    session.commit()
except:
    session.rollback()
    raise
finally:
    session.close()
cursor.close()
cnx.close()

# %%
pop_table
# Out:
#             서비스링크     표준링크아이디
# 0      1000000100  1000022501
# 1      1000000100  1000022502
# 2      1000000200  1000022401
# 3      1000000200  1000022402
# 4      1000000300  1000000301
# ...           ...         ...
# 11515  3201510300  1130040000
# 11516  3201510600  1130039700
# 11517  3201510600  1130040400
# 11518  3201510700  1130040300
# 11519  3201510700  1130039600
#
# [11520 rows x 2 columns]

# %%
pop_table.values.tolist()
# Out:
# [[1000000100, 1000022501],
#  [1000000100, 1000022502],
#  [1000000200, 1000022401],
#  [1000000200, 1000022402],
#  [1000000300, 1000000301],
#  [1000000300, 1000000302],
#  [1000000300, 1000000303],
#  [1000000400, 1000000403],
#  [1000000400, 1000000402],
#  [1000000400, 1000000401],
#  [1000000500, 1000000503],
#  [1000000500, 1000000502],
#  [1000000500, 1000000501],
#  [1000000600, 1000000601],
#  [1000000600, 1000000602],
#  [1000000600, 1000000603],
#  [1000000700, 1000000703],
#  [1000000700, 1000000702],
#  [1000000700, 1000000701],
#  [1000000800, 1000000801],
#  [1000000800, 1000000802],
#  [1000000800, 1000000803],
#  [1000000900, 1000000903],
#  [1000000900, 1000000902],
#  [1000000900, 1000000901],
#  [1000001000, 1000001001],
#  [1000001000, 1000001002],
#  [1000001000, 1000001003],
#  [1000001100, 1000001102],
#  [1000001100, 1000001101],
#  [1000001200, 1000001201],
#  [1000001200, 1000001202],
#  [1000001300, 1000001303],
#  [1000001300, 1000001302],
# ...

# %%
pop_table.columns
# Out:
# Index(['서비스링크', '표준링크아이디'], dtype='object')

# %%
# Out:
#             서비스링크     표준링크아이디
# 0      1000000100  1000022501
# 1      1000000100  1000022502
# 2      1000000200  1000022401
# 3      1000000200  1000022402
# 4      1000000300  1000000301
# ...           ...         ...
# 11515  3201510300  1130040000
# 11516  3201510600  1130039700
# 11517  3201510600  1130040400
# 11518  3201510700  1130040300
# 11519  3201510700  1130039600
#
# [11520 rows x 2 columns]
